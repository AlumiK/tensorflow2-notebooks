# %% [markdown]
# # CNN Improved (CIFAR-10)

# %%
import itertools
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

from sklearn.metrics import confusion_matrix

# %%
# !nvidia-smi -L
print(f'Tensorflow version: {tf.__version__}')
# Out:
# GPU 0: GeForce RTX 2080 Ti (UUID: GPU-3cb47403-efa9-71ae-1700-c27de6cb0d0a)
# Tensorflow version: 2.3.1

# %%
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.cifar10.load_data()
X_train, X_test = X_train / 255.0, X_test / 255.0
y_train, y_test = y_train.flatten(), y_test.flatten()

K = len(set(y_train.flatten()))
BATCH_SIZE = 32

# %%
i = tf.keras.layers.Input(shape=X_train[0].shape)
x = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', padding='same')(i)
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.MaxPooling2D((2, 2))(x)
x = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.MaxPooling2D((2, 2))(x)
x = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same')(x)
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same')(x)
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.MaxPooling2D((2, 2))(x)
x = tf.keras.layers.Flatten()(x)
x = tf.keras.layers.Dropout(0.2)(x)
x = tf.keras.layers.Dense(1024, activation='relu')(x)
x = tf.keras.layers.Dropout(0.2)(x)
x = tf.keras.layers.Dense(K, activation='softmax')(x)
model = tf.keras.models.Model(i, x)

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

data_generator = tf.keras.preprocessing.image.ImageDataGenerator(width_shift_range=0.1,
                                                                 height_shift_range=0.1,
                                                                 horizontal_flip=True)
train_generator = data_generator.flow(X_train, y_train, BATCH_SIZE)
steps_per_epoch = X_train.shape[0] // BATCH_SIZE

r = model.fit(train_generator,
              validation_data=(X_test, y_test),
              steps_per_epoch=steps_per_epoch,
              epochs=30)

plt.plot(r.history.get('loss'), label='Loss')
plt.plot(r.history.get('val_loss'), label='Validation Loss')
plt.legend()
plt.show()

plt.plot(r.history.get('accuracy'), label='Accuracy')
plt.plot(r.history.get('val_accuracy'), label='Validation Accuracy')
plt.legend()
plt.show()

print(f'Accuracy: {model.evaluate(X_test, y_test)[1]}')
# Out:
# Epoch 1/30
# 1562/1562 [==============================] - 16s 10ms/step - loss: 1.4045 - accuracy: 0.5083 - val_loss: 1.0477 - val_accuracy: 0.6345
# Epoch 2/30
# 1562/1562 [==============================] - 16s 10ms/step - loss: 0.9758 - accuracy: 0.6613 - val_loss: 0.8458 - val_accuracy: 0.7085
# Epoch 3/30
# 1562/1562 [==============================] - 16s 10ms/step - loss: 0.8455 - accuracy: 0.7105 - val_loss: 0.9358 - val_accuracy: 0.6938
# Epoch 4/30
# 1562/1562 [==============================] - 16s 10ms/step - loss: 0.7502 - accuracy: 0.7429 - val_loss: 0.8641 - val_accuracy: 0.7147
# Epoch 5/30
# 1562/1562 [==============================] - 16s 10ms/step - loss: 0.6839 - accuracy: 0.7675 - val_loss: 0.8622 - val_accuracy: 0.7293
# Epoch 6/30
# 1562/1562 [==============================] - 16s 10ms/step - loss: 0.6295 - accuracy: 0.7862 - val_loss: 0.6761 - val_accuracy: 0.7768
# Epoch 7/30
# 1562/1562 [==============================] - 16s 10ms/step - loss: 0.5933 - accuracy: 0.7982 - val_loss: 0.5627 - val_accuracy: 0.8125
# Epoch 8/30
# 1562/1562 [==============================] - 16s 10ms/step - loss: 0.5568 - accuracy: 0.8113 - val_loss: 0.5592 - val_accuracy: 0.8139
# Epoch 9/30
# 1562/1562 [==============================] - 16s 10ms/step - loss: 0.5255 - accuracy: 0.8215 - val_loss: 0.5752 - val_accuracy: 0.8117
# Epoch 10/30
# 1562/1562 [==============================] - 15s 10ms/step - loss: 0.4959 - accuracy: 0.8312 - val_loss: 0.6867 - val_accuracy: 0.7821
# Epoch 11/30
# 1562/1562 [==============================] - 15s 10ms/step - loss: 0.4732 - accuracy: 0.8399 - val_loss: 0.4986 - val_accuracy: 0.8335
# Epoch 12/30
# 1562/1562 [==============================] - 15s 10ms/step - loss: 0.4553 - accuracy: 0.8440 - val_loss: 0.5515 - val_accuracy: 0.8169
# Epoch 13/30
# 1562/1562 [==============================] - 15s 10ms/step - loss: 0.4213 - accuracy: 0.8567 - val_loss: 0.5569 - val_accuracy: 0.8257
# Epoch 14/30
# 1562/1562 [==============================] - 16s 10ms/step - loss: 0.4061 - accuracy: 0.8600 - val_loss: 0.4965 - val_accuracy: 0.8410
# Epoch 15/30
# 1562/1562 [==============================] - 16s 10ms/step - loss: 0.3974 - accuracy: 0.8637 - val_loss: 0.4400 - val_accuracy: 0.8552
# Epoch 16/30
# 1562/1562 [==============================] - 16s 10ms/step - loss: 0.3777 - accuracy: 0.8715 - val_loss: 0.5449 - val_accuracy: 0.8227
# Epoch 17/30
# 1562/1562 [==============================] - 16s 10ms/step - loss: 0.3630 - accuracy: 0.8749 - val_loss: 0.4497 - val_accuracy: 0.8563
# Epoch 18/30
# 1562/1562 [==============================] - 16s 10ms/step - loss: 0.3552 - accuracy: 0.8794 - val_loss: 0.5306 - val_accuracy: 0.8267
# Epoch 19/30
# 1562/1562 [==============================] - 16s 10ms/step - loss: 0.3370 - accuracy: 0.8837 - val_loss: 0.4092 - val_accuracy: 0.8632
# Epoch 20/30
# 1562/1562 [==============================] - 16s 10ms/step - loss: 0.3369 - accuracy: 0.8841 - val_loss: 0.4960 - val_accuracy: 0.8378
# Epoch 21/30
# 1562/1562 [==============================] - 16s 10ms/step - loss: 0.3212 - accuracy: 0.8898 - val_loss: 0.4332 - val_accuracy: 0.8600
# Epoch 22/30
# 1562/1562 [==============================] - 16s 10ms/step - loss: 0.3101 - accuracy: 0.8945 - val_loss: 0.4294 - val_accuracy: 0.8608
# Epoch 23/30
# 1562/1562 [==============================] - 16s 10ms/step - loss: 0.3037 - accuracy: 0.8949 - val_loss: 0.4844 - val_accuracy: 0.8441
# Epoch 24/30
# 1562/1562 [==============================] - 16s 10ms/step - loss: 0.2972 - accuracy: 0.8984 - val_loss: 0.3906 - val_accuracy: 0.8744
# Epoch 25/30
# 1562/1562 [==============================] - 16s 10ms/step - loss: 0.2891 - accuracy: 0.9009 - val_loss: 0.4016 - val_accuracy: 0.8707
# Epoch 26/30
# 1562/1562 [==============================] - 16s 10ms/step - loss: 0.2752 - accuracy: 0.9062 - val_loss: 0.4230 - val_accuracy: 0.8664
# Epoch 27/30
# 1562/1562 [==============================] - 16s 10ms/step - loss: 0.2694 - accuracy: 0.9077 - val_loss: 0.4177 - val_accuracy: 0.8750
# Epoch 28/30
# 1562/1562 [==============================] - 16s 10ms/step - loss: 0.2660 - accuracy: 0.9092 - val_loss: 0.4269 - val_accuracy: 0.8646
# Epoch 29/30
# 1562/1562 [==============================] - 16s 10ms/step - loss: 0.2621 - accuracy: 0.9097 - val_loss: 0.4164 - val_accuracy: 0.8681
# Epoch 30/30
# 1562/1562 [==============================] - 16s 10ms/step - loss: 0.2572 - accuracy: 0.9111 - val_loss: 0.4149 - val_accuracy: 0.8666
# 313/313 [==============================] - 0s 2ms/step - loss: 0.4149 - accuracy: 0.8666
# Accuracy: 0.866599977016449

# %% [markdown]
# ## Plot the confusion matrix

# %%
def plot_confusion_matrix(cm, labels):
    plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
    plt.title('Confusion Matrix')
    plt.colorbar()
    num_classes = len(labels)
    tick_marks = np.arange(num_classes)
    plt.xticks(tick_marks, labels, rotation=90)
    plt.yticks(tick_marks, labels)
    
    threshold = cm.max() / 2
    for i, j in itertools.product(range(num_classes), range(num_classes)):
        plt.text(j, i, cm[i, j],
                 ha='center',
                 color='white' if cm[i, j] > threshold else 'black')

    plt.tight_layout()
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    plt.show()


labels = [
    'Airplane', 
    'Automobile',
    'Bird',
    'Cat',
    'Deer',
    'Dog',
    'Frog',
    'Horse',
    'Ship',
    'Truck',
]

p_test = model.predict(X_test).argmax(axis=1)
cm = confusion_matrix(y_test, p_test)
plot_confusion_matrix(cm, labels)

# %% [markdown]
# ## Display a random misclassified image

# %%
misclassified_idx = np.where(p_test != y_test)[0]
i = np.random.choice(misclassified_idx)
plt.imshow(X_test[i])
plt.title(f'Truth: {labels[y_test[i]]}\nPredicted: {labels[p_test[i]]}')
plt.show()
