# %% [markdown]
# # CNN Improved (CIFAR-10)

# %%
import itertools
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

from sklearn.metrics import confusion_matrix

# %%
# !nvidia-smi -L
# Out:
# GPU 0: GeForce RTX 2080 Ti (UUID: GPU-3cb47403-efa9-71ae-1700-c27de6cb0d0a)

# %%
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.cifar10.load_data()
X_train, X_test = X_train / 255.0, X_test / 255.0
y_train, y_test = y_train.flatten(), y_test.flatten()

K = len(set(y_train.flatten()))
BATCH_SIZE = 32

# %%
i = tf.keras.layers.Input(shape=X_train[0].shape)
x = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', padding='same')(i)
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.MaxPooling2D((2, 2))(x)
x = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.MaxPooling2D((2, 2))(x)
x = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same')(x)
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same')(x)
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.MaxPooling2D((2, 2))(x)
x = tf.keras.layers.Flatten()(x)
x = tf.keras.layers.Dropout(0.2)(x)
x = tf.keras.layers.Dense(1024, activation='relu')(x)
x = tf.keras.layers.Dropout(0.2)(x)
x = tf.keras.layers.Dense(K, activation='softmax')(x)
model = tf.keras.models.Model(i, x)

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

data_generator = tf.keras.preprocessing.image.ImageDataGenerator(width_shift_range=0.1,
                                                                 height_shift_range=0.1,
                                                                 horizontal_flip=True)
train_generator = data_generator.flow(X_train, y_train, BATCH_SIZE)
steps_per_epoch = X_train.shape[0] // BATCH_SIZE

r = model.fit(train_generator,
              validation_data=(X_test, y_test),
              steps_per_epoch=steps_per_epoch,
              epochs=30)

plt.plot(r.history.get('loss'), label='Loss')
plt.plot(r.history.get('val_loss'), label='Validation Loss')
plt.legend()
plt.show()

plt.plot(r.history.get('accuracy'), label='Accuracy')
plt.plot(r.history.get('val_accuracy'), label='Validation Accuracy')
plt.legend()
plt.show()

print(f'Accuracy: {model.evaluate(X_test, y_test)[1]}')
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 1562 steps, validate on 10000 samples
# Epoch 1/30
# 1562/1562 [==============================] - 19s 12ms/step - loss: 1.4280 - accuracy: 0.5034 - val_loss: 1.2622 - val_accuracy: 0.5656
# Epoch 2/30
# 1562/1562 [==============================] - 16s 11ms/step - loss: 0.9878 - accuracy: 0.6532 - val_loss: 0.9309 - val_accuracy: 0.6826
# Epoch 3/30
# 1562/1562 [==============================] - 17s 11ms/step - loss: 0.8398 - accuracy: 0.7114 - val_loss: 0.7784 - val_accuracy: 0.7338
# Epoch 4/30
# 1562/1562 [==============================] - 17s 11ms/step - loss: 0.7511 - accuracy: 0.7433 - val_loss: 0.6872 - val_accuracy: 0.7652
# Epoch 5/30
# 1562/1562 [==============================] - 17s 11ms/step - loss: 0.6783 - accuracy: 0.7689 - val_loss: 0.7738 - val_accuracy: 0.7428
# Epoch 6/30
# 1562/1562 [==============================] - 17s 11ms/step - loss: 0.6236 - accuracy: 0.7865 - val_loss: 0.7888 - val_accuracy: 0.7498
# Epoch 7/30
# 1562/1562 [==============================] - 17s 11ms/step - loss: 0.5881 - accuracy: 0.7992 - val_loss: 0.6378 - val_accuracy: 0.7924
# Epoch 8/30
# 1562/1562 [==============================] - 17s 11ms/step - loss: 0.5485 - accuracy: 0.8129 - val_loss: 0.6170 - val_accuracy: 0.8010
# Epoch 9/30
# 1562/1562 [==============================] - 16s 10ms/step - loss: 0.5113 - accuracy: 0.8249 - val_loss: 0.5449 - val_accuracy: 0.8180
# Epoch 10/30
# 1562/1562 [==============================] - 16s 10ms/step - loss: 0.4885 - accuracy: 0.8338 - val_loss: 0.5665 - val_accuracy: 0.8123
# Epoch 11/30
# 1562/1562 [==============================] - 16s 10ms/step - loss: 0.4620 - accuracy: 0.8419 - val_loss: 0.5898 - val_accuracy: 0.8118
# Epoch 12/30
# 1562/1562 [==============================] - 16s 10ms/step - loss: 0.4381 - accuracy: 0.8496 - val_loss: 0.5535 - val_accuracy: 0.8180
# Epoch 13/30
# 1562/1562 [==============================] - 16s 10ms/step - loss: 0.4210 - accuracy: 0.8547 - val_loss: 0.4863 - val_accuracy: 0.8406
# Epoch 14/30
# 1562/1562 [==============================] - 16s 11ms/step - loss: 0.3984 - accuracy: 0.8631 - val_loss: 0.4425 - val_accuracy: 0.8500
# Epoch 15/30
# 1562/1562 [==============================] - 16s 11ms/step - loss: 0.3827 - accuracy: 0.8689 - val_loss: 0.4665 - val_accuracy: 0.8414
# Epoch 16/30
# 1562/1562 [==============================] - 17s 11ms/step - loss: 0.3700 - accuracy: 0.8722 - val_loss: 0.4496 - val_accuracy: 0.8516
# Epoch 17/30
# 1562/1562 [==============================] - 17s 11ms/step - loss: 0.3518 - accuracy: 0.8802 - val_loss: 0.5521 - val_accuracy: 0.8259
# Epoch 18/30
# 1562/1562 [==============================] - 17s 11ms/step - loss: 0.3425 - accuracy: 0.8822 - val_loss: 0.4917 - val_accuracy: 0.8382
# Epoch 19/30
# 1562/1562 [==============================] - 17s 11ms/step - loss: 0.3294 - accuracy: 0.8860 - val_loss: 0.4451 - val_accuracy: 0.8575
# Epoch 20/30
# 1562/1562 [==============================] - 16s 10ms/step - loss: 0.3205 - accuracy: 0.8886 - val_loss: 0.4692 - val_accuracy: 0.8507
# Epoch 21/30
# 1562/1562 [==============================] - 16s 10ms/step - loss: 0.3067 - accuracy: 0.8932 - val_loss: 0.4406 - val_accuracy: 0.8589
# Epoch 22/30
# 1562/1562 [==============================] - 17s 11ms/step - loss: 0.2986 - accuracy: 0.8966 - val_loss: 0.4051 - val_accuracy: 0.8636
# Epoch 23/30
# 1562/1562 [==============================] - 16s 11ms/step - loss: 0.2858 - accuracy: 0.9019 - val_loss: 0.4954 - val_accuracy: 0.8432
# Epoch 24/30
# 1562/1562 [==============================] - 17s 11ms/step - loss: 0.2831 - accuracy: 0.9016 - val_loss: 0.4088 - val_accuracy: 0.8676
# Epoch 25/30
# 1562/1562 [==============================] - 17s 11ms/step - loss: 0.2731 - accuracy: 0.9052 - val_loss: 0.4416 - val_accuracy: 0.8605
# Epoch 26/30
# 1562/1562 [==============================] - 17s 11ms/step - loss: 0.2658 - accuracy: 0.9085 - val_loss: 0.4369 - val_accuracy: 0.8604
# Epoch 27/30
# 1562/1562 [==============================] - 17s 11ms/step - loss: 0.2624 - accuracy: 0.9100 - val_loss: 0.4191 - val_accuracy: 0.8664
# Epoch 28/30
# 1562/1562 [==============================] - 17s 11ms/step - loss: 0.2482 - accuracy: 0.9132 - val_loss: 0.4171 - val_accuracy: 0.8708
# Epoch 29/30
# 1562/1562 [==============================] - 17s 11ms/step - loss: 0.2476 - accuracy: 0.9141 - val_loss: 0.3996 - val_accuracy: 0.8759
# Epoch 30/30
# 1562/1562 [==============================] - 16s 10ms/step - loss: 0.2404 - accuracy: 0.9147 - val_loss: 0.4408 - val_accuracy: 0.8577
# 10000/10000 [==============================] - 1s 59us/sample - loss: 0.4408 - accuracy: 0.8577
# Accuracy: 0.857699990272522

# %% [markdown]
# ## Plot the confusion matrix

# %%
def plot_confusion_matrix(cm, labels):
    plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
    plt.title('Confusion Matrix')
    plt.colorbar()
    num_classes = len(labels)
    tick_marks = np.arange(num_classes)
    plt.xticks(tick_marks, labels, rotation=90)
    plt.yticks(tick_marks, labels)
    
    threshold = cm.max() / 2
    for i, j in itertools.product(range(num_classes), range(num_classes)):
        plt.text(j, i, cm[i, j],
                 ha='center',
                 color='white' if cm[i, j] > threshold else 'black')

    plt.tight_layout()
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    plt.show()


labels = [
    'Airplane', 
    'Automobile',
    'Bird',
    'Cat',
    'Deer',
    'Dog',
    'Frog',
    'Horse',
    'Ship',
    'Truck',
]

p_test = model.predict(X_test).argmax(axis=1)
cm = confusion_matrix(y_test, p_test)
plot_confusion_matrix(cm, labels)

# %% [markdown]
# ## Display a random misclassified image

# %%
misclassified_idx = np.where(p_test != y_test)[0]
i = np.random.choice(misclassified_idx)
plt.imshow(X_test[i])
plt.title(f'Truth: {labels[y_test[i]]}\nPredicted: {labels[p_test[i]]}')
plt.show()
