# %% [markdown]
# # Simple RNN

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split

# %%
# !nvidia-smi -L
print(f'Tensorflow version: {tf.__version__}')
# Out:
# GPU 0: GeForce RTX 2080 Ti (UUID: GPU-3cb47403-efa9-71ae-1700-c27de6cb0d0a)
# Tensorflow version: 2.3.1

# %%
series = np.sin(0.1 * np.arange(200)) + 0.1 * np.random.randn(200)
plt.plot(series)
plt.show()

T = 10
D = 1
X = []
y = []
for t in range(len(series) - T):
    X.append(series[t:t + T])
    y.append(series[t + T])
X = np.asarray(X).reshape(-1, T, D)
y = np.asarray(y)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, shuffle=False)

# %%
i = tf.keras.layers.Input(shape=(T, 1))
x = tf.keras.layers.SimpleRNN(5, activation=None)(i)
x = tf.keras.layers.Dense(1)(x)
model = tf.keras.models.Model(i, x)

model.compile(optimizer=tf.keras.optimizers.Adam(0.1),
              loss='mse')

r = model.fit(X_train, y_train,
              validation_data=(X_test, y_test),
              epochs=50)

plt.plot(r.history.get('loss'), label='Loss')
plt.plot(r.history.get('val_loss'), label='Validation Loss')
plt.legend()
plt.show()
# Out:
# Epoch 1/50
# 3/3 [==============================] - 0s 51ms/step - loss: 1.6966 - val_loss: 0.8697
# Epoch 2/50
# 3/3 [==============================] - 0s 8ms/step - loss: 0.3459 - val_loss: 0.0971
# Epoch 3/50
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0550 - val_loss: 0.1129
# Epoch 4/50
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0948 - val_loss: 0.0598
# Epoch 5/50
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0524 - val_loss: 0.0666
# Epoch 6/50
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0753 - val_loss: 0.0802
# Epoch 7/50
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0684 - val_loss: 0.0449
# Epoch 8/50
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0559 - val_loss: 0.0471
# Epoch 9/50
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0481 - val_loss: 0.0328
# Epoch 10/50
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0424 - val_loss: 0.0347
# Epoch 11/50
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0402 - val_loss: 0.0259
# Epoch 12/50
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0323 - val_loss: 0.0317
# Epoch 13/50
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0324 - val_loss: 0.0237
# Epoch 14/50
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0245 - val_loss: 0.0217
# Epoch 15/50
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0263 - val_loss: 0.0212
# Epoch 16/50
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0225 - val_loss: 0.0248
# Epoch 17/50
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0223 - val_loss: 0.0188
# Epoch 18/50
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0198 - val_loss: 0.0185
# Epoch 19/50
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0184 - val_loss: 0.0180
# Epoch 20/50
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0178 - val_loss: 0.0175
# Epoch 21/50
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0166 - val_loss: 0.0178
# Epoch 22/50
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0160 - val_loss: 0.0205
# Epoch 23/50
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0164 - val_loss: 0.0195
# Epoch 24/50
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0177 - val_loss: 0.0169
# Epoch 25/50
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0156 - val_loss: 0.0160
# Epoch 26/50
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0148 - val_loss: 0.0158
# Epoch 27/50
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0149 - val_loss: 0.0153
# Epoch 28/50
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0145 - val_loss: 0.0153
# Epoch 29/50
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0157 - val_loss: 0.0150
# Epoch 30/50
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0143 - val_loss: 0.0152
# Epoch 31/50
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0152 - val_loss: 0.0161
# Epoch 32/50
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0163 - val_loss: 0.0177
# Epoch 33/50
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0161 - val_loss: 0.0154
# Epoch 34/50
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0153 - val_loss: 0.0156
# Epoch 35/50
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0146 - val_loss: 0.0151
# Epoch 36/50
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0148 - val_loss: 0.0147
# Epoch 37/50
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0142 - val_loss: 0.0148
# Epoch 38/50
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0146 - val_loss: 0.0168
# Epoch 39/50
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0173 - val_loss: 0.0162
# Epoch 40/50
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0155 - val_loss: 0.0155
# Epoch 41/50
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0162 - val_loss: 0.0164
# Epoch 42/50
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0155 - val_loss: 0.0148
# Epoch 43/50
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0142 - val_loss: 0.0149
# Epoch 44/50
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0154 - val_loss: 0.0149
# Epoch 45/50
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0150 - val_loss: 0.0148
# Epoch 46/50
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0146 - val_loss: 0.0152
# Epoch 47/50
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0147 - val_loss: 0.0148
# Epoch 48/50
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0142 - val_loss: 0.0149
# Epoch 49/50
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0142 - val_loss: 0.0148
# Epoch 50/50
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0144 - val_loss: 0.0147

# %% [markdown]
# ## One-step forecast

# %%
forecast = []
for i in range(len(y_test)):
    p = model.predict(X_test[i].reshape(1, T, D))[0, 0]
    forecast.append(p)

plt.plot(y_test, label='Truth')
plt.plot(forecast, label='Forecast')
plt.legend()
plt.show()

# %% [markdown]
# ## Multi-step forecast

# %%
forecast = []
last_x = X_train[-1]
for i in range(len(y_test)):
    p = model.predict(last_x.reshape(1, T, D))[0, 0]
    forecast.append(p)
    last_x = np.roll(last_x, -1)
    last_x[-1] = p

plt.plot(y_test, label='Truth')
plt.plot(forecast, label='Forecast')
plt.legend()
plt.show()
