# %% [markdown]
# # Simple RNN

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split

# %%
# !nvidia-smi -L
# Out:
# GPU 0: GeForce RTX 2080 Ti (UUID: GPU-3cb47403-efa9-71ae-1700-c27de6cb0d0a)

# %%
series = np.sin(0.1 * np.arange(200)) + 0.1 * np.random.randn(200)
plt.plot(series)
plt.show()

T = 10
D = 1
X = []
y = []
for t in range(len(series) - T):
    X.append(series[t:t + T])
    y.append(series[t + T])
X = np.asarray(X).reshape(-1, T, D)
y = np.asarray(y)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, shuffle=False)

# %%
i = tf.keras.layers.Input(shape=(T, 1))
x = tf.keras.layers.SimpleRNN(5, activation=None)(i)
x = tf.keras.layers.Dense(1)(x)
model = tf.keras.models.Model(i, x)

model.compile(optimizer=tf.keras.optimizers.Adam(0.1),
              loss='mse')

r = model.fit(X_train, y_train,
              validation_data=(X_test, y_test),
              epochs=50)

plt.plot(r.history.get('loss'), label='Loss')
plt.plot(r.history.get('val_loss'), label='Validation Loss')
plt.legend()
plt.show()
# Out:
# Train on 95 samples, validate on 95 samples
# Epoch 1/50
# 95/95 [==============================] - 1s 9ms/sample - loss: 1.1261 - val_loss: 0.2843
# Epoch 2/50
# 95/95 [==============================] - 0s 219us/sample - loss: 0.2227 - val_loss: 0.1269
# Epoch 3/50
# 95/95 [==============================] - 0s 225us/sample - loss: 0.0898 - val_loss: 0.0547
# Epoch 4/50
# 95/95 [==============================] - 0s 221us/sample - loss: 0.0436 - val_loss: 0.0415
# Epoch 5/50
# 95/95 [==============================] - 0s 214us/sample - loss: 0.0446 - val_loss: 0.0608
# Epoch 6/50
# 95/95 [==============================] - 0s 219us/sample - loss: 0.0427 - val_loss: 0.0324
# Epoch 7/50
# 95/95 [==============================] - 0s 209us/sample - loss: 0.0286 - val_loss: 0.0299
# Epoch 8/50
# 95/95 [==============================] - 0s 219us/sample - loss: 0.0311 - val_loss: 0.0318
# Epoch 9/50
# 95/95 [==============================] - 0s 214us/sample - loss: 0.0306 - val_loss: 0.0261
# Epoch 10/50
# 95/95 [==============================] - 0s 214us/sample - loss: 0.0294 - val_loss: 0.0255
# Epoch 11/50
# 95/95 [==============================] - 0s 209us/sample - loss: 0.0284 - val_loss: 0.0400
# Epoch 12/50
# 95/95 [==============================] - 0s 209us/sample - loss: 0.0329 - val_loss: 0.0239
# Epoch 13/50
# 95/95 [==============================] - 0s 209us/sample - loss: 0.0250 - val_loss: 0.0248
# Epoch 14/50
# 95/95 [==============================] - 0s 230us/sample - loss: 0.0242 - val_loss: 0.0233
# Epoch 15/50
# 95/95 [==============================] - 0s 209us/sample - loss: 0.0240 - val_loss: 0.0241
# Epoch 16/50
# 95/95 [==============================] - 0s 219us/sample - loss: 0.0248 - val_loss: 0.0249
# Epoch 17/50
# 95/95 [==============================] - 0s 209us/sample - loss: 0.0220 - val_loss: 0.0229
# Epoch 18/50
# 95/95 [==============================] - 0s 216us/sample - loss: 0.0215 - val_loss: 0.0259
# Epoch 19/50
# 95/95 [==============================] - 0s 209us/sample - loss: 0.0229 - val_loss: 0.0249
# Epoch 20/50
# 95/95 [==============================] - 0s 218us/sample - loss: 0.0247 - val_loss: 0.0297
# Epoch 21/50
# 95/95 [==============================] - 0s 216us/sample - loss: 0.0226 - val_loss: 0.0248
# Epoch 22/50
# 95/95 [==============================] - 0s 214us/sample - loss: 0.0199 - val_loss: 0.0235
# Epoch 23/50
# 95/95 [==============================] - 0s 209us/sample - loss: 0.0207 - val_loss: 0.0231
# Epoch 24/50
# 95/95 [==============================] - 0s 214us/sample - loss: 0.0203 - val_loss: 0.0257
# Epoch 25/50
# 95/95 [==============================] - 0s 216us/sample - loss: 0.0199 - val_loss: 0.0242
# Epoch 26/50
# 95/95 [==============================] - 0s 215us/sample - loss: 0.0204 - val_loss: 0.0234
# Epoch 27/50
# 95/95 [==============================] - 0s 209us/sample - loss: 0.0189 - val_loss: 0.0222
# Epoch 28/50
# 95/95 [==============================] - 0s 206us/sample - loss: 0.0187 - val_loss: 0.0224
# Epoch 29/50
# 95/95 [==============================] - 0s 230us/sample - loss: 0.0211 - val_loss: 0.0402
# Epoch 30/50
# 95/95 [==============================] - 0s 220us/sample - loss: 0.0289 - val_loss: 0.0256
# Epoch 31/50
# 95/95 [==============================] - 0s 209us/sample - loss: 0.0252 - val_loss: 0.0315
# Epoch 32/50
# 95/95 [==============================] - 0s 224us/sample - loss: 0.0229 - val_loss: 0.0271
# Epoch 33/50
# 95/95 [==============================] - 0s 214us/sample - loss: 0.0209 - val_loss: 0.0272
# Epoch 34/50
# 95/95 [==============================] - 0s 214us/sample - loss: 0.0218 - val_loss: 0.0243
# Epoch 35/50
# 95/95 [==============================] - 0s 219us/sample - loss: 0.0225 - val_loss: 0.0289
# Epoch 36/50
# 95/95 [==============================] - 0s 209us/sample - loss: 0.0233 - val_loss: 0.0259
# Epoch 37/50
# 95/95 [==============================] - 0s 219us/sample - loss: 0.0220 - val_loss: 0.0241
# Epoch 38/50
# 95/95 [==============================] - 0s 219us/sample - loss: 0.0194 - val_loss: 0.0220
# Epoch 39/50
# 95/95 [==============================] - 0s 219us/sample - loss: 0.0184 - val_loss: 0.0218
# Epoch 40/50
# 95/95 [==============================] - 0s 219us/sample - loss: 0.0201 - val_loss: 0.0213
# Epoch 41/50
# 95/95 [==============================] - 0s 219us/sample - loss: 0.0197 - val_loss: 0.0215
# Epoch 42/50
# 95/95 [==============================] - 0s 214us/sample - loss: 0.0177 - val_loss: 0.0218
# Epoch 43/50
# 95/95 [==============================] - 0s 225us/sample - loss: 0.0171 - val_loss: 0.0225
# Epoch 44/50
# 95/95 [==============================] - 0s 224us/sample - loss: 0.0175 - val_loss: 0.0243
# Epoch 45/50
# 95/95 [==============================] - 0s 225us/sample - loss: 0.0190 - val_loss: 0.0229
# Epoch 46/50
# 95/95 [==============================] - 0s 225us/sample - loss: 0.0200 - val_loss: 0.0231
# Epoch 47/50
# 95/95 [==============================] - 0s 219us/sample - loss: 0.0217 - val_loss: 0.0223
# Epoch 48/50
# 95/95 [==============================] - 0s 230us/sample - loss: 0.0163 - val_loss: 0.0222
# Epoch 49/50
# 95/95 [==============================] - 0s 219us/sample - loss: 0.0190 - val_loss: 0.0228
# Epoch 50/50
# 95/95 [==============================] - 0s 215us/sample - loss: 0.0175 - val_loss: 0.0287

# %% [markdown]
# ## One-step forecast

# %%
forecast = []
for i in range(len(y_test)):
    p = model.predict(X_test[i].reshape(1, T, D))[0, 0]
    forecast.append(p)

plt.plot(y_test, label='Truth')
plt.plot(forecast, label='Forecast')
plt.legend()
plt.show()

# %% [markdown]
# ## Multi-step forecast

# %%
forecast = []
last_x = X_train[-1]
for i in range(len(y_test)):
    p = model.predict(last_x.reshape(1, T, D))[0, 0]
    forecast.append(p)
    last_x = np.roll(last_x, -1)
    last_x[-1] = p

plt.plot(y_test, label='Truth')
plt.plot(forecast, label='Forecast')
plt.legend()
plt.show()
